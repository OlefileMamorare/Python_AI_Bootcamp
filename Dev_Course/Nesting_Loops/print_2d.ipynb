# %%
def print2d(matrix):
    for row in matrix:
        for item in row:
            print(item)

array1 = [
    ["a", "b", "c", "d"],
    ["e", "f"],
    ["g", "h", "i"]
]

print2d(array1)
#
# Out:
# a
# b
# c
# d
# e
# f
# g
# h
# i
