# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
import google.generativeai as genai
import os

# %%
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
for model in genai.list_models():
    print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview

# %%
#Generating Text From Text Prompts

model = genai.GenerativeModel("gemini-2.5-flash")
response = model.generate_content("Explain the concept of Quantum Computing in simple terms.")

# %%
print(response.text)
# Out:
# Imagine computers as incredibly fast calculators. For decades, they've worked using a very simple idea: **bits**.
#
# ### Classical Computers and "Bits"
#
# Think of a light switch. It can be either **ON (1)** or **OFF (0)**. That's a "bit." A classical computer solves problems by flicking billions of these switches, one at a time, in a specific sequence. It processes information by representing everything as 0s and 1s.
#
# For example, if you want to find the best route from A to B among many options, a classical computer essentially tries each route one by one (very, very quickly) until it finds the optimal one.
#
# ### Quantum Computers and "Qubits"
#
# Now, imagine a **quantum light switch**. This is a **qubit**. Here's where it gets mind-bending:
#
# 1.  **Superposition (Being ON and OFF at the same time):**
#     *   A classical bit is either 0 or 1.
#     *   A qubit, thanks to the rules of quantum mechanics, can be 0, 1, **or a combination of both at the same time!**
#     *   **Analogy:** Think of a spinning coin. While it's spinning in the air, it's neither heads nor tails – it's both simultaneously, in a state of "superposition." Only when it lands (or you "measure" it) does it become definitively heads or tails.
#     *   This means a single qubit can hold vastly more information than a single classical bit. Two qubits can be in four superposed states simultaneously, three qubits in eight, and so on. The number of states grows exponentially!
#
# 2.  **Entanglement (Spooky Connection):**
#     *   When two or more qubits become "entangled," they are linked in a way that the state of one instantly influences the state of the others, no matter how far apart they are.
#     *   **Analogy:** Imagine you have two perfectly synchronized magic coins. You flip them both in separate rooms, without seeing them. If you look at one and it's heads, you instantly *know* the other one *must* be tails, even without looking at it. They're intrinsically connected.
#     *   This allows qubits to perform incredibly complex calculations together, sharing information in ways classical bits cannot.
#
# ### How Quantum Computers Solve Problems (The "Magic")
#
# Because qubits can be in multiple states at once (superposition) and influence each other instantly (entanglement), a quantum computer doesn't have to try one solution after another like a classical computer.
#
# Instead, it can explore **many, many possibilities simultaneously.**
#
# **Analogy:**
# *   **Classical Computer:** Trying to find the right key for a locked door, you try one key at a time until you find the one that works.
# *   **Quantum Computer:** Imagine you could magically try *all the keys at once* and the door just *opens* with the right one, because all the wrong keys somehow "cancel each other out," leaving only the solution.
#
# They don't necessarily "try" every path; rather, they exploit quantum phenomena to increase the probability of arriving at the correct answer and decrease the probability of wrong ones, quickly converging on a solution.
#
# ### What are they good for?
#
# Quantum computers are not meant to replace your laptop or smartphone. They are designed to solve very specific, incredibly complex problems that are practically impossible for even the most powerful classical supercomputers. This includes:
#
# *   **Drug Discovery & Material Science:** Simulating molecules and chemical reactions at a fundamental level to design new medicines, superconductors, or more efficient batteries.
# *   **Cryptography:** Breaking today's most secure encryption methods and creating new, unhackable ones.
# *   **Optimization:** Finding the absolute best solution for problems with countless variables, like logistics for delivery networks, financial modeling, or traffic flow.
# *   **Artificial Intelligence:** Supercharging machine learning algorithms to process vast amounts of data and recognize patterns more effectively.
#
# ### In Simple Terms:
#
# Quantum computing uses tiny particles that can exist in multiple states at once (superposition) and be mysteriously linked (entanglement). This allows them to process vast amounts of information and explore countless possibilities **simultaneously**, making them incredibly powerful for solving certain complex problems that are beyond the reach of even the fastest traditional computers. It's like having a computer that can walk down every path in a maze at the same time, instead of just one at a time.

# %%
model_info = genai.get_model("gemini-2.5-flash")
print(model_info)
# Out:
# Model(name='models/gemini-2.5-flash',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 2.5 Flash',
#       description=('Stable version of Gemini 2.5 Flash, our mid-size multimodal model that '
#                    'supports up to 1 million tokens, released in June of 2025.'),
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent',
#                                     'countTokens',
#                                     'createCachedContent',
#                                     'batchGenerateContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
