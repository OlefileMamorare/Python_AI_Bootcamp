# %%
from dotenv import load_dotenv
from openai import OpenAI
load_dotenv()

#developer_message = 'You are a high-school tutor.'


client = OpenAI()


stream = client.responses.create(
    model="gpt-4o-mini",
    instructions= 'You are a high-school tutor.',
    input='Explain Quantum Mechanics to teenagers.',
    stream=True,
)

#print(response.output_text)
print('AI is typing....\n')
for event in stream:
    if event.type == "response.output_text.delta":
        print(event.delta, end="", flush=True)

print()
# Out:
# AI is typing....
#
# Sure! Let’s break down quantum mechanics in a way that's relatable.
#
# ### What is Quantum Mechanics?
#
# **Quantum Mechanics** is a branch of physics that deals with very tiny particles, like atoms and subatomic particles (electrons, protons, etc.). It explains how these tiny bits of matter behave differently from the larger objects we're used to, like cars or basketballs.
#
# ### Key Concepts:
#
# 1. **Particles and Waves**: In the quantum world, particles (like electrons) can act like both particles and waves. This means they can sometimes behave like little balls and sometimes like waves of energy. Think of the way water ripples; that's similar to how particles can move as waves.
#
# 2. **Quantum Superposition**: This idea means that particles can exist in multiple states at once until they're observed. For example, imagine rolling a die. Until you look at it, the die is in a mix of all possible numbers (1 through 6) at the same time. Once you look, it "collapses" into one specific number.
#
# 3. **Quantum Entanglement**: This is a really cool concept where two particles can become linked. If something happens to one particle, the other one will be affected instantly, no matter how far apart they are. Imagine having two magic dice; if you roll one and it shows a 6, the other one, no matter how far away, will also show a 6 instantly!
#
# 4. **Uncertainty Principle**: This principle, introduced by Werner Heisenberg, says that you can’t know both the position and the momentum (how fast it's moving) of a particle with perfect accuracy at the same time. The more precisely you know where it is, the less precisely you can know its speed, and vice versa. It’s like trying to catch a very slippery fish—the moment you grab it, you might not know where it swam from!
#
# 5. **Quantum Tunneling**: This phenomenon occurs when particles pass through barriers that they shouldn’t be able to cross, according to classical physics. Imagine trying to climb a steep hill. In the quantum world, particles can "tunnel" through the hill instead of climbing over it.
#
# ### Why Does It Matter?
#
# Quantum mechanics is crucial for many technologies we use today, such as:
#
# - **Lasers**: Which are based on quantum principles and have many applications, from cutting metals to laser pointers.
# - **Computers**: Quantum computers are being developed to process information much faster than traditional computers.
# - **Medical Imaging**: Techniques like MRI use principles of quantum mechanics.
#
# ### Final Thought
#
# Quantum mechanics might seem strange and counterintuitive, but it helps us understand the very fabric of the universe! It challenges our ideas about reality, showing that things can be unpredictable at a fundamental level. It's like a peek into a bizarre and fascinating world that operates differently than anything we see every day.

# %%
from openai import OpenAI
client = OpenAI()

stream = client.responses.create(
    model="gpt-5",
    input=[
        {
            "role": "user",
            "content": "Say 'double bubble bath' ten times fast.",
        },
    ],
    stream=True,
)

for event in stream:
    print(event)
# Out:
# ResponseCreatedEvent(response=Response(id='resp_0352c7abf1406907006994a817d0b8819087114f3d11278131', created_at=1771350039.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-2025-08-07', object='response', output=[], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, completed_at=None, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='medium', generate_summary=None, summary=None), safety_identifier=None, service_tier='auto', status='in_progress', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=None, user=None, frequency_penalty=0.0, presence_penalty=0.0, store=True), sequence_number=0, type='response.created')
# ResponseInProgressEvent(response=Response(id='resp_0352c7abf1406907006994a817d0b8819087114f3d11278131', created_at=1771350039.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-2025-08-07', object='response', output=[], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, completed_at=None, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='medium', generate_summary=None, summary=None), safety_identifier=None, service_tier='auto', status='in_progress', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=None, user=None, frequency_penalty=0.0, presence_penalty=0.0, store=True), sequence_number=1, type='response.in_progress')
# ResponseOutputItemAddedEvent(item=ResponseReasoningItem(id='rs_0352c7abf1406907006994a8183de48190af971c219547112b', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), output_index=0, sequence_number=2, type='response.output_item.added')
# ResponseOutputItemDoneEvent(item=ResponseReasoningItem(id='rs_0352c7abf1406907006994a8183de48190af971c219547112b', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), output_index=0, sequence_number=3, type='response.output_item.done')
# ResponseOutputItemAddedEvent(item=ResponseOutputMessage(id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', content=[], role='assistant', status='in_progress', type='message'), output_index=1, sequence_number=4, type='response.output_item.added')
# ResponseContentPartAddedEvent(content_index=0, item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', output_index=1, part=ResponseOutputText(annotations=[], text='', type='output_text', logprobs=[]), sequence_number=5, type='response.content_part.added')
# ResponseTextDeltaEvent(content_index=0, delta='double', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=6, type='response.output_text.delta', obfuscation='ZszUnUzmXV')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=7, type='response.output_text.delta', obfuscation='KdD0BlPk3')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=8, type='response.output_text.delta', obfuscation='yN3vaZLguva')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=9, type='response.output_text.delta', obfuscation='XhXfRYJZb')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=10, type='response.output_text.delta', obfuscation='TaoDnGkgw')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=11, type='response.output_text.delta', obfuscation='EMTEgWRZRRg')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=12, type='response.output_text.delta', obfuscation='FimAGGy16')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=13, type='response.output_text.delta', obfuscation='aqV2LpCkN')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=14, type='response.output_text.delta', obfuscation='jQpsUGqGLAJ')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=15, type='response.output_text.delta', obfuscation='mCSVtavSo')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=16, type='response.output_text.delta', obfuscation='qpLoItXeY')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=17, type='response.output_text.delta', obfuscation='LodQrpV4FuN')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=18, type='response.output_text.delta', obfuscation='c91arIMFx')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=19, type='response.output_text.delta', obfuscation='1634nw9DU')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=20, type='response.output_text.delta', obfuscation='a9RmsVBrXx3')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=21, type='response.output_text.delta', obfuscation='qgG190GPR')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=22, type='response.output_text.delta', obfuscation='vBbrrla1u')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=23, type='response.output_text.delta', obfuscation='hixzLgDMe09')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=24, type='response.output_text.delta', obfuscation='1nJpGMkdI')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=25, type='response.output_text.delta', obfuscation='JTXocJmFR')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=26, type='response.output_text.delta', obfuscation='SW5t9YB3m9C')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=27, type='response.output_text.delta', obfuscation='OjpOyqW4d')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=28, type='response.output_text.delta', obfuscation='EQSbUfsRN')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=29, type='response.output_text.delta', obfuscation='KBc45LQX6v8')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=30, type='response.output_text.delta', obfuscation='SQWcXmBvp')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=31, type='response.output_text.delta', obfuscation='Qsu1vjvhF')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=32, type='response.output_text.delta', obfuscation='hXpqoHObxSJ')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=33, type='response.output_text.delta', obfuscation='y1Z2i2wIp')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=34, type='response.output_text.delta', obfuscation='4WMy3oSR7')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=35, type='response.output_text.delta', obfuscation='DY3iKbEqLyg')
# ResponseTextDoneEvent(content_index=0, item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', logprobs=[], output_index=1, sequence_number=36, text='double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath', type='response.output_text.done')
# ResponseContentPartDoneEvent(content_index=0, item_id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', output_index=1, part=ResponseOutputText(annotations=[], text='double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath', type='output_text', logprobs=[]), sequence_number=37, type='response.content_part.done')
# ResponseOutputItemDoneEvent(item=ResponseOutputMessage(id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', content=[ResponseOutputText(annotations=[], text='double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath', type='output_text', logprobs=[])], role='assistant', status='completed', type='message'), output_index=1, sequence_number=38, type='response.output_item.done')
# ResponseCompletedEvent(response=Response(id='resp_0352c7abf1406907006994a817d0b8819087114f3d11278131', created_at=1771350039.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-2025-08-07', object='response', output=[ResponseReasoningItem(id='rs_0352c7abf1406907006994a8183de48190af971c219547112b', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), ResponseOutputMessage(id='msg_0352c7abf1406907006994a81ef8208190862c62dfbc7ac7ad', content=[ResponseOutputText(annotations=[], text='double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, completed_at=1771350047.0, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='medium', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=16, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=452, output_tokens_details=OutputTokensDetails(reasoning_tokens=384), total_tokens=468), user=None, frequency_penalty=0.0, presence_penalty=0.0, store=True), sequence_number=39, type='response.completed')
