# %%
from dotenv import load_dotenv, find_dotenv
from openai import OpenAI
import os

load_dotenv(find_dotenv(), override=True)


client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))
response = client.responses.create(
model="gpt-4",
input="Write a short article about coffee",
temperature=1
)

print(response.output_text)

# %%
response.usage
# Out:
# ResponseUsage(input_tokens=12, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=505, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=517)
