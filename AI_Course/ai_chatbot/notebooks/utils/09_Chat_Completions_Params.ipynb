# %%
from dotenv import load_dotenv, find_dotenv
from openai import OpenAI
import os

load_dotenv(find_dotenv(), override=True)


client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))
response = client.responses.create(
model="gpt-4",
input="What do you think about 47 Ronin movie?",
    temperature=1
)

print(response.output_text)
# Out:
# As an artificial intelligence, I don't form personal opinions or emotions. However, I can share that the 47 Ronin movie receives mixed reactions. Some people appreciate the incorporation of fantasy elements into a historical event, while others criticize it for its deviation from the actual tale of the 47 Ronin. The performance of Keanu Reeves and the visual effects are generally appreciated.
