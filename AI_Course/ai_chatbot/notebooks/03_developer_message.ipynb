# %%
from dotenv import load_dotenv
from openai import OpenAI
load_dotenv()

developer_message = 'You are a concise assistant. You reply briefly with no elaboration.'


client = OpenAI()


response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        {'role': 'developer', 'content': developer_message},
        {'role': 'user', 'content': 'Explain Object_Oriented Programming with Python.'}
    ]
)

print(response.output_text)
# Out:
# Object-Oriented Programming (OOP) in Python is a programming paradigm that uses "objects" to represent data and methods. Key concepts include:
#
# 1. **Classes**: Blueprints for creating objects.
# 2. **Objects**: Instances of classes.
# 3. **Encapsulation**: Bundling data and methods, restricting access.
# 4. **Inheritance**: Creating new classes from existing ones.
# 5. **Polymorphism**: Using the same method name for different behaviors.
#
# Example:
#
# ```python
# class Animal:
#     def speak(self):
#         print("Animal speaks")
#
# class Dog(Animal):
#     def speak(self):
#         print("Woof!")
#
# dog = Dog()
# dog.speak()  # Outputs: Woof!
# ```
